# %% [markdown]
# <a href="https://colab.research.google.com/github/geotech-ia/natalidad_cali/blob/main/Graficas_nacimientos_87_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conexión del contenido del Drive Geotech IA Solutions a cuaderno de Google Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Importar librería Pandas y la tabla de nacimientos por barrios de estratos 5 y 6 en Cali y creacion del Data Frame

# %%
import pandas as pd
data_route = '/content/gdrive/MyDrive/Nacimientos_1987_2017_barrios.csv'
df = pd.read_csv(data_route)

# %% [markdown]
# Consulta de la primera fila de la tabla importada correspondiente al barrio con mayor numero de nacimientos ocurridos entre 1987 y 2017 en viviendas de estratos 5 y 6 en Cali

# %%
df.iloc[0]
# Out:
# barrio    Parcelaciones Pance
# total                    4328
# nac_87                     97
# nac_88                    107
# nac_89                     99
# nac_90                    120
# nac_91                    120
# nac_92                    123
# nac_93                    147
# nac_94                    155
# nac_95                    154
# nac_96                    176
# nac_97                    203
# nac_98                    195
# nac_99                    184
# nac_00                    162
# nac_01                    150
# nac_02                    181
# nac_03                    149
# nac_04                    174
# nac_05                    136
# nac_06                    177
# nac_07                    148
# nac_08                    133
# nac_09                    141
# nac_10                    122
# nac_11                    126
# nac_12                    137
# nac_13                    111
# nac_14                    114
# nac_15                    118
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fecha = ['87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99', '00', '01', '02', '03', '04', '05', '06', '07',
         '08', '09', '10', '11', '12', '13', '14', '15', '16', '17']
parcelaciones_pance = df.iloc[2]
lili = df.iloc[3]
hacienda = df.iloc[4]
ingenio = df.iloc[5]
caney = df.iloc[6]
urbanizacion_la_flora = df.iloc[7]
senderos_de_la_flora = df.iloc[8]
urb_ciudad_jardin = df.iloc[9]
ciudad_capri = df.iloc[10]
mayapan_las_vegas = df.iloc[11]

fig, ax = plt.subplots()
ax.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')

indices_lista = np.arange(0, len(fecha), 5)
elementos_seleccionados = [fecha[i] for i in indices_lista]
posiciones_etiquetas = np.array(elementos_seleccionados)
ax.set_xticks(posiciones_etiquetas)
etiquetas = [f'{i}' for i in posiciones_etiquetas]
ax.set_xticklabels(etiquetas)

# Select only the numerical data for plotting, excluding 'barrio' and 'total'
#plt.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')
plt.xlabel('Año')
plt.ylabel('Número de nacimientos por año')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fecha = ['87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99', '00', '01', '02', '03', '04', '05', '06', '07',
         '08', '09', '10', '11', '12', '13', '14', '15', '16', '17']
parcelaciones_pance = df.iloc[2]
lili = df.iloc[3]
hacienda = df.iloc[4]
ingenio = df.iloc[5]
caney = df.iloc[6]
urbanizacion_la_flora = df.iloc[7]
senderos_de_la_flora = df.iloc[8]
urb_ciudad_jardin = df.iloc[9]
ciudad_capri = df.iloc[10]
mayapan_las_vegas = df.iloc[11]

fig, ax = plt.subplots()
ax.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')

indices_lista = np.arange(0, len(fecha), 5)
elementos_seleccionados = [fecha[i] for i in indices_lista]
posiciones_etiquetas = np.array(elementos_seleccionados)
ax.set_xticks(posiciones_etiquetas)
etiquetas = [f'{i}' for i in posiciones_etiquetas]
ax.set_xticklabels(etiquetas)

# Select only the numerical data for plotting, excluding 'barrio' and 'total'
#plt.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')
plt.xlabel('Año')
plt.ylabel('Número de nacimientos por año')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fecha = ['87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99', '00', '01', '02', '03', '04', '05', '06', '07',
         '08', '09', '10', '11', '12', '13', '14', '15', '16', '17']
parcelaciones_pance = df.iloc[2]
lili = df.iloc[3]
hacienda = df.iloc[4]
ingenio = df.iloc[5]
caney = df.iloc[6]
urbanizacion_la_flora = df.iloc[7]
senderos_de_la_flora = df.iloc[8]
urb_ciudad_jardin = df.iloc[9]
ciudad_capri = df.iloc[10]
mayapan_las_vegas = df.iloc[11]

fig, ax = plt.subplots()
ax.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')
ax.plot(fecha, lili[2:], color = 'red', linewidth = 1, label = 'Lili')
ax.plot(fecha, ingenio[2:], color = 'orange', linewidth = 1, label = 'Ingenio')
ax.plot(fecha, urbanizacion_la_flora[2:], color = 'brown', linewidth = 1, label = 'Urbanización La Flora')
ax.plot(fecha, senderos_de_la_flora[2:], color = 'black', linewidth = 1, label = 'Senderos de la Flora')
indices_lista = np.arange(0, len(fecha), 5)
elementos_seleccionados = [fecha[i] for i in indices_lista]
posiciones_etiquetas = np.array(elementos_seleccionados)
ax.set_xticks(posiciones_etiquetas)
etiquetas = [f'{i}' for i in posiciones_etiquetas]
ax.set_xticklabels(etiquetas)

# Select only the numerical data for plotting, excluding 'barrio' and 'total'
#plt.plot(fecha, parcelaciones_pance[2:], color = 'blue', linewidth = 1, label = 'Parcelaciones Pance')
plt.xlabel('Año')
plt.ylabel('Número de nacimientos por año')
plt.legend()
plt.show()

# %% [markdown]
# Construccion de grafica de tendencia de natalidad para los 10 barrios con mayores indices en Cali -  años 1987 a 2017
